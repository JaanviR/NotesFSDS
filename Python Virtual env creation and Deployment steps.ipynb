# %%
## Mac terminal commands cheat sheet for reference 
## https://www.makeuseof.com/tag/mac-terminal-commands-cheat-sheet/

# %%
## Step (Common) : Open Terminal in vscode and cd into application/folder where your program files(app.py etc.,) are

# Flask python virtual environment

'''

Step - 1 : python3 -m venv nameofenvironment
eg: python3 -m venv demo
Step - 2 : select python interpreter (view->commandpalette->python:select interpreter(choose the path)) the path will consist the name of the virtual environment (demo) you created
Step - 3 : source nameofenvironment/bin/activate
eg: source demo/bin/activate
Step - 4 : pip3 install -r requirements.txt
Step - 5 : python3 -m flask run

'''

# Django python virtual environment

'''
Step - 1 : python3 -m venv nameofenvironment
eg: python3 -m venv demo
Step - 2 : select python interpreter (view->commandpalette->python:select interpreter(choose the path)) the path will consist the name of the virtual environment (demo) you created
Step - 3 : source nameofenvironment/bin/activate
eg: source demo/bin/activate
Step - 4 : pip3 install -r requirements.txt
Step - 5 : python3 manage.py makemigrations
Step - 6 : python3 manage.py migrate
Step - 7 : python3 manage.py createsuperuser(ignore this if already super user is created)
Step - 8 : python3 manage.py runserver

'''

# Flask conda virtual environment

'''
Step - 1 : conda create -n env-01 python=3.7.9 scipy=0.15.0 astroid babel (we have to mention python=requiredversion scipy=version or another libraries which are required to run that particular application)
eg: conda create -n demo python=3.7.9
Step - 2 : select python interpreter (view->commandpalette->python:select interpreter(choose the path)) the path will consist the name of the virtual environment (demo) you created along 'conda' name
Step - 3 : conda activate nameofenvironment
eg: conda activate demo
Step - 4 : pip3 install -r requirements.txt
Step - 5 : python3 -m flask run

'''

# Django conda virtual environment

'''
Step - 1 : conda create -n env-01 python=3.7.9 scipy=0.15.0 astroid babel (we have to mention python=requiredversion scipy=version or another libraries which are required to run that particular application)
eg: conda create -n demo python=3.7.9
Step - 2 : select python interpreter (view->commandpalette->python:select interpreter(choose the path)) the path will consist the name of the virtual environment (demo) you created along 'conda' name
Step - 3 : conda activate nameofenvironment
eg: conda activate demo
Step - 4 : pip3 install -r requirements.txt
Step - 5 : python3 manage.py makemigrations
Step - 6 : python3 manage.py migrate
Step - 7 : python3 manage.py createsuperuser(ignore this if already super user is created)
Step - 8 : python3 manage.py runserver

'''

# %%
## Deployment on Heroku
'''
Step - 1 : Signup / Login into Herouku account 
Step - 2 : Download heroku cli for mac ( for this to be installed we should have homebrew installed on mac )
Note: If brew is already installed then skip to Step - 4

Step - 3 :
Homebrew installation steps:
a. Open terminal on your system and type the following command 
xcode-select --install
b . After this check whether x-code cli is installed or not by typing th following command
xcode-select -p
c . Now you can install home brew by using the following command
/usr/bin/ruby -e "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/master/install)"
d. You can confirm whether brew is installed or not by using the following command
brew doctor
If you don't see any error after using the above command then you can say that brew is successfully installed on your system

Step - 4 : After installing homebrew you can install heroku cli by using the following command
brew tap heroku/brew && brew install heroku
Step - 5 : Verify heroku installation by running the following command
heroku --version 
Step - 6 : We need to install gitpython by using the following command
pip3 install GitPython

The following steps are common to deploy the code into heroku platform whenever you want to deploy an app

Step - 7 : login into heroku account from terminal using the following command
heroku login
Step - 8 : cd into your project
Step - 9 : git init
Step - 10 : heroku git:remote -a projectname(same as the app name which you created on heroku)
Step - 11 : git add .
Step - 12 : git commit -am "any message of your choice(like first deployment, app deploy etc., this message is for your reference only, it will be helpful when you make changes to the existing code and to keep track of new changes)"
Step - 13 : git push heroku master

Pushing the code to heroku after making changing something in the code(for eg: if you changed the bg color of the app, then you can follow the same steps  )
 git add .
 git commit -am "changed color"
 git push heroku master


Check out the link below to get the details of changes you made to the code
https://devcenter.heroku.com/articles/releases 
eg: git log -n 1 de63889
(the above example gives us the information about a change made in that particular deployment version(de63889))


Rolling back to previous versions on heroku,
go to Activity tab on Heroku and click on "Roll back here" (related to that particular version)


Cloning the copy of  code from heroku --> check out 31st july 2021 recording --> (1:55:00)timestamp

'''
